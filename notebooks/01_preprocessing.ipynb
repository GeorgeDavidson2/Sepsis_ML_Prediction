# %% [markdown]
# # Notebook 01 — Data Pipeline & Preprocessing
#
# ## Requires
# - `data/raw/training_setA/` and `data/raw/training_setB/` (downloaded dataset)
#
# ## Produces
# - `data/splits/train_ids.csv`
# - `data/splits/val_ids.csv`
# - `data/splits/test_ids.csv`
# - `data/processed/strategy_A_simple/`
# - `data/processed/strategy_B_missingness_aware/`
# - `results/models/strategy_A_imputer.pkl`
# - `results/models/strategy_A_scaler.pkl`
# - `results/models/strategy_B_imputer.pkl`
# - `results/models/strategy_B_scaler.pkl`
# - `results/models/strategy_B_feature_names.pkl`
#
# ## Run Order
# Run **AFTER** notebook 00. All condition notebooks (02–05) depend on outputs from this notebook.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
from pathlib import Path

from src.config import (
    RANDOM_SEED, DATA_DIR, PROCESSED_DIR, SPLITS_DIR,
    MODELS_DIR, ALL_FEATURES, VITAL_SIGNS, LAB_VALUES,
    OUTLIER_BOUNDS, LABEL_SHIFT_HOURS, SPLIT_RATIOS
)
from src.data_loader import load_all_patients
from src.preprocessing import engineer_labels, clip_outliers, apply_strategy_A, apply_strategy_B
from src.features import add_lag_features
from src.utils import set_all_seeds, validate_no_nans, create_patient_splits

set_all_seeds(RANDOM_SEED)
Path(SPLITS_DIR).mkdir(parents=True, exist_ok=True)
Path(MODELS_DIR).mkdir(parents=True, exist_ok=True)

print('Imports OK')
