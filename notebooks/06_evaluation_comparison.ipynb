# %% [markdown]
# # Notebook 06 — Full 2×2 Evaluation & Comparison
#
# ## Requires
# - `results/metrics/condition_A.csv`, `condition_B.csv`, `condition_C.csv`, `condition_D.csv` (all 4 conditions must be complete)
# - `results/models/xgb_condition_A.pkl`, `xgb_condition_B.pkl` (for SHAP analysis)
# - `data/splits/test_ids.csv` (for patient-level bootstrap resampling)
#
# ## Produces
# - `results/figures/roc_curves.png`
# - `results/figures/pr_curves.png`
# - `results/figures/sensitivity_specificity_bar.png`
# - `results/figures/calibration_plot.png`
# - `results/figures/shap_condition_A_bar.png`
# - `results/figures/shap_condition_A_beeswarm.png`
# - `results/figures/shap_condition_B_bar.png`
# - `results/figures/shap_condition_B_beeswarm.png`
# - `results/figures/hospital_generalizability.png`
# - `results/metrics/2x2_comparison_table.csv`
# - `results/metrics/hospital_generalizability.csv`
#
# ## Run Order
# Run **LAST** — after all 4 condition notebooks (02, 03, 04, 05) are complete.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import shap
from sklearn.metrics import roc_curve, precision_recall_curve
from sklearn.calibration import calibration_curve

from src.config import RANDOM_SEED, MODELS_DIR, METRICS_DIR, FIGURES_DIR, N_BOOTSTRAP
from src.utils import set_all_seeds
from src.evaluate import select_threshold, compute_all_metrics, bootstrap_ci

set_all_seeds(RANDOM_SEED)

print('Imports OK')
